# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already satisfied: sklearn in c:\users\micha\anaconda3.1\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\micha\anaconda3.1\lib\site-packages (from sklearn) (0.24.2)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\micha\anaconda3.1\lib\site-packages (from scikit-learn->sklearn) (1.20.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\micha\anaconda3.1\lib\site-packages (from scikit-learn->sklearn) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\micha\anaconda3.1\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\micha\anaconda3.1\lib\site-packages (from scikit-learn->sklearn) (1.7.1)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\micha\anaconda3.1\lib\site-packages (1.1.0)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("./Resources/exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.keys()
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
X = df.drop('koi_disposition', axis=1)
X.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %% [markdown]
# # Create a Train Test Split

# %% [markdown]
# Use koi_disposition for the y values

# %%
y = df['koi_disposition']
target_names = ["confirmed","false positive"]
y
# Out:
# 0            CONFIRMED
# 1       FALSE POSITIVE
# 2       FALSE POSITIVE
# 3            CONFIRMED
# 4            CONFIRMED
#              ...
# 6986    FALSE POSITIVE
# 6987    FALSE POSITIVE
# 6988         CANDIDATE
# 6989    FALSE POSITIVE
# 6990    FALSE POSITIVE
# Name: koi_disposition, Length: 6991, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 4723              0              0              0              0    3.131839
# 3614              0              0              0              0   54.649368
# 4                 0              0              0              0    4.134435
# 6196              0              0              0              1    0.566790
# 1366              0              0              0              0   16.726197
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 4723         0.000682        -0.000682    132.12300           0.18100
# 3614         0.000971        -0.000971    176.04470           0.01640
# 4            0.000010        -0.000010    172.97937           0.00190
# 6196         0.000007        -0.000007    131.81846           0.00957
# 1366         0.000148        -0.000148    143.74673           0.00675
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 4723          -0.18100  ...            -195      4.246           0.215
# 3614          -0.01640  ...             -78      4.234           0.149
# 4             -0.00190  ...            -232      4.486           0.054
# 6196          -0.00957  ...            -142      4.600           0.028
# 1366          -0.00675  ...             -75      4.331           0.132
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 4723          -0.218     1.159          0.385         -0.253  292.32944
# 3614          -0.108     1.282          0.215         -0.215  290.59039
# 4             -0.229     0.972          0.315         -0.105  296.28613
# 6196          -0.028     0.758          0.336         -0.049  291.70813
# 1366          -0.108     1.100          0.164         -0.147  289.38800
#
#             dec  koi_kepmag
# 4723  47.835629      14.122
# 3614  45.439709      15.335
# 4     48.224670      15.714
# 6196  42.969410      13.767
# 1366  50.597050      14.514
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing

# %% [markdown]
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.svm import SVC
svm_model = SVC(kernel='linear')
svm_model.fit(X_train_scaled, y_train)
# Out:
# SVC(kernel='linear')

# %%
predictions = svm_model.predict(X_test_scaled)

# %%
print(f"Training Data Score: {svm_model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {svm_model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.8388327293534236
# Testing Data Score: 0.8586956521739131

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                           target_names =["CONFIRMED", "FALSE POSITIVE", "CANDIDATE"]))
# Out:
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.73      0.63      0.68       394
# FALSE POSITIVE       0.71      0.77      0.74       445
#      CANDIDATE       0.98      1.00      0.99       909
#
#       accuracy                           0.86      1748
#      macro avg       0.81      0.80      0.80      1748
#   weighted avg       0.86      0.86      0.86      1748

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# Use GridSearchCV to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV

param_grid = {
    'kernel':['linear', 'rbf'],
    'C': [1, 5, 10, 50],
    'gamma': [0.0001, 0.0005, 0.001, 0.01]}
grid_SVM = GridSearchCV(svm_model, param_grid, verbose=3)

# %%
# List the parameters
svm_model.get_params().keys()
# Out:
# dict_keys(['C', 'break_ties', 'cache_size', 'class_weight', 'coef0', 'decision_function_shape', 'degree', 'gamma', 'kernel', 'max_iter', 'probability', 'random_state', 'shrinking', 'tol', 'verbose'])

# %%
# Train the model with GridSearch
grid_SVM.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.825 total time=   0.3s
# [CV 2/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.838 total time=   0.2s
# [CV 3/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.834 total time=   0.2s
# [CV 4/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.836 total time=   0.2s
# [CV 5/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.836 total time=   0.2s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.495 total time=   2.0s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.495 total time=   2.0s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.495 total time=   1.8s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.495 total time=   1.6s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.495 total time=   1.6s
# [CV
5] END ....C=50, gamma=0.0001, kernel=rbf;, score=0.738 total time=   1.6s
# [CV 5/5] END ....C=50, gamma=0.0001, kernel=rbf;, score=0.732 total time=   1.5s
# [CV 1/5] END .C=50, gamma=0.0005, kernel=linear;, score=0.867 total time=   0.5s
# [CV 2/5] END .C=50, gamma=0.0005, kernel=linear;, score=0.875 total time=   0.5s
# [CV 3/5] END .C=50, gamma=0.0005, kernel=linear;, score=0.882 total time=   0.4s
# [CV 4/5] END .C=50, gamma=0.0005, kernel=linear;, score=0.871 total time=   0.5s
# [CV 5/5] END .C=50, gamma=0.0005, kernel=linear;, score=0.877 total time=   0.5s
# [CV 1/5] END ....C=50, gamma=0.0005, kernel=rbf;, score=0.795 total time=   0.9s
# [CV 2/5] END ....C=50, gamma=0.0005, kernel=rbf;, score=0.811 total time=   1.0s
# [CV 3/5] END ....C=50, gamma=0.0005, kernel=rbf;, score=0.803 total time=   0.8s
# [CV 4/5] END ....C=50, gamma=0.0005, kernel=rbf;, score=0.806 total time=   1.0s
# [CV 5/5] END ....C=50, gamma=0.0005, kernel=rbf;, score=0.799 total time=   0.9s
# [CV 1/5] END ..C=50, gamma=0.001, kernel=linear;, score=0.867 total time=   0.5s
# [CV 2/5] END ..C=50, gamma=0.001, kernel=linear;, score=0.875 total time=   0.4s
# [CV 3/5] END ..C=50, gamma=0.001, kernel=linear;, score=0.882 total time=   0.4s
# [CV 4/5] END ..C=50, gamma=0.001, kernel=linear;, score=0.871 total time=   0.5s
# [CV 5/5] END ..C=50, gamma=0.001, kernel=linear;, score=0.877 total time=   0.7s
# [CV 1/5] END .....C=50, gamma=0.001, kernel=rbf;, score=0.796 total time=   0.9s
# [CV 2/5] END .....C=50, gamma=0.001, kernel=rbf;, score=0.821 total time=   0.9s
# [CV 3/5] END .....C=50, gamma=0.001, kernel=rbf;, score=0.820 total time=   0.9s
# [CV 4/5] END .....C=50, gamma=0.001, kernel=rbf;, score=0.830 total time=   0.8s
# [CV 5/5] END .....C=50, gamma=0.001, kernel=rbf;, score=0.807 total time=   0.7s
# [CV 1/5] END ...C=50, gamma=0.01, kernel=linear;, score=0.867 total time=   0.5s
# [CV 2/5] END ...C=50, gamma=0.01, kernel=linear;, score=0.875 total time=   0.4s
# [CV 3/5] END ...C=50, gamma=0.01, kernel=linear;, score=0.882 total time=   0.5s
# [CV 4/5] END ...C=50, gamma=0.01, kernel=linear;, score=0.871 total time=   0.4s
# [CV 5/5] END ...C=50, gamma=0.01, kernel=linear;, score=0.877 total time=   0.5s
# [CV 1/5] END ......C=50, gamma=0.01, kernel=rbf;, score=0.826 total time=   1.2s
# [CV 2/5] END ......C=50, gamma=0.01, kernel=rbf;, score=0.838 total time=   0.9s
# [CV 3/5] END ......C=50, gamma=0.01, kernel=rbf;, score=0.832 total time=   0.7s
# [CV 4/5] END ......C=50, gamma=0.01, kernel=rbf;, score=0.838 total time=   0.7s
# [CV 5/5] END ......C=50, gamma=0.01, kernel=rbf;, score=0.839 total time=   0.8s
# GridSearchCV(estimator=SVC(kernel='linear'),
#              param_grid={'C': [1, 5, 10, 50],
#                          'gamma': [0.0001, 0.0005, 0.001, 0.01],
#                          'kernel': ['linear', 'rbf']},
#              verbose=3)

# %%
print(grid_SVM.best_params_)
print(grid_SVM.best_score_)
# Out:
# {'C': 50, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.874499159504872

# %%
# Make predictions with the hypertuned model
predictions = grid_SVM.predict(X_test_scaled)
predictions
# Out:
# array(['FALSE POSITIVE', 'FALSE POSITIVE', 'FALSE POSITIVE', ...,
#        'CONFIRMED', 'CONFIRMED', 'CANDIDATE'], dtype=object)

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                           target_names =["CONFIRMED", "FALSE POSITIVE", "CANDIDATE"]))
# Out:
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.84      0.71      0.77       394
# FALSE POSITIVE       0.78      0.85      0.81       445
#      CANDIDATE       0.98      1.00      0.99       909
#
#       accuracy                           0.90      1748
#      macro avg       0.87      0.85      0.86      1748
#   weighted avg       0.90      0.90      0.90      1748

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'best_models/exoplanet_svm.sav'
joblib.dump(grid_SVM, filename)
# Out:
# ['best_models/exoplanet_svm.sav']
